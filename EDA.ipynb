# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
table = pd.read_csv('dataset.csv')
table
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (208,225,255,257,260,270,271,277) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Duration (in seconds) What is your age (# years)?  \
# 0                        121                       30-34
# 1                        462                       30-34
# 2                        293                       18-21
# 3                        851                       55-59
# 4                        232                       45-49
# ...                      ...                         ...
# 23992                    331                       22-24
# 23993                    330                       60-69
# 23994                    860                       25-29
# 23995                    597                       35-39
# 23996                    303                       18-21
#
# ...

# %%
table = table.fillna("")
table
# Out:
#        Duration (in seconds) What is your age (# years)?  \
# 0                        121                       30-34
# 1                        462                       30-34
# 2                        293                       18-21
# 3                        851                       55-59
# 4                        232                       45-49
# ...                      ...                         ...
# 23992                    331                       22-24
# 23993                    330                       60-69
# 23994                    860                       25-29
# 23995                    597                       35-39
# 23996                    303                       18-21
#
#       What is your gender? - Selected Choice  \
# 0                                        Man
# 1                                        Man
# 2                                        Man
# 3                                        Man
# 4                                        Man
# ...

# %%
table["Platform"] = table[["On which platforms have you begun or completed data science courses? (Select all that apply) - Selected Choice - Coursera","On which platforms have you begun or completed data science courses? (Select all that apply) - Selected Choice - edX",	"On which platforms have you begun or completed data science courses? (Select all that apply) - Selected Choice - Kaggle Learn Courses"	,"On which platforms have you begun or completed data science courses? (Select all that apply) - Selected Choice - DataCamp"	,"On which platforms have you begun or completed data science courses? (Select all that apply) - Selected Choice - Fast.ai"	,"On which platforms have you begun or completed data science courses? (Select all that apply) - Selected Choice - Udacity",	"On which platforms have you begun or completed data science courses? (Select all that apply) - Selected Choice - Udemy"	,"On which platforms have you begun or completed data science courses? (Select all that apply) - Selected Choice - LinkedIn Learning",	"On which platforms have you begun or completed data science courses? (Select all that apply) - Selected Choice - Cloud-certification programs (direct from AWS, Azure, GCP, or similar)",	"On which platforms have you begun or completed data science courses? (Select all that apply) - Selected Choice - University Courses (resulting in a university degree)"	,"On which platforms have you begun or completed data science courses? (Select all that apply) - Selected Choice - None",	"On which platforms have you begun or completed data science courses? (Select all that apply) - Selected Choice - Other"]].apply(lambda x: " ".join(x), axis =1)
table
# Out:
#        Duration (in seconds) What is your age (# years)?  \
# 0                        121                       30-34
# 1                        462                       30-34
# 2                        293                       18-21
# 3                        851                       55-59
# 4                        232                       45-49
# ...                      ...                         ...
# 23992                    331                       22-24
# 23993                    330                       60-69
# 23994                    860                       25-29
# 23995                    597                       35-39
# 23996                    303                       18-21
#
#       What is your gender? - Selected Choice  \
# 0                                        Man
# 1                                        Man
# 2                                        Man
# 3                                        Man
# 4                                        Man
# ...

# %%
Platform =table["Platform"]
Platform.head()
# Out:
# 0                                                Other
# 1             University Courses (resulting in a un...
# 2    Coursera edX  DataCamp  Udacity Udemy LinkedIn...
# 3    Coursera  Kaggle Learn Courses    Udemy     Other
# 4                                                Other
# Name: Platform, dtype: object

# %%
table['Most helpful product and platform'] = table[table.columns[17:24]].apply(
    lambda x: ' '.join(x.dropna().astype(str)),
    axis=1
)
table
# Out:
#        Duration (in seconds) What is your age (# years)?  \
# 0                        121                       30-34
# 1                        462                       30-34
# 2                        293                       18-21
# 3                        851                       55-59
# 4                        232                       45-49
# ...                      ...                         ...
# 23992                    331                       22-24
# 23993                    330                       60-69
# 23994                    860                       25-29
# 23995                    597                       35-39
# 23996                    303                       18-21
#
#       What is your gender? - Selected Choice  \
# 0                                        Man
# 1                                        Man
# 2                                        Man
# 3                                        Man
# 4                                        Man
# ...

# %%
Helpful_product_platform =table["Most helpful product and platform"]
Helpful_product_platform.head()
# Out:
# 0
# 1    University courses    Kaggle (notebooks, compe...
# 2     Online courses (Coursera, EdX, etc)  Video pl...
# 3     Online courses (Coursera, EdX, etc)   Kaggle ...
# 4                             University courses
# Name: Most helpful product and platform, dtype: object

# %%
table['Useful ide'] = table[table.columns[45:57]].apply(
    lambda x: ' '.join(x.dropna().astype(str)),
    axis=1
)
table
# Out:
#        Duration (in seconds) What is your age (# years)?  \
# 0                        121                       30-34
# 1                        462                       30-34
# 2                        293                       18-21
# 3                        851                       55-59
# 4                        232                       45-49
# ...                      ...                         ...
# 23992                    331                       22-24
# 23993                    330                       60-69
# 23994                    860                       25-29
# 23995                    597                       35-39
# 23996                    303                       18-21
#
#       What is your gender? - Selected Choice  \
# 0                                        Man
# 1                                        Man
# 2                                        Man
# 3                                        Man
# 4                                        Man
# ...

# %%
ide =table["Useful ide"]
ide.head()
# Out:
# 0
# 1                                     Notepad++
# 2              JupyterLab            Jupyter Notebook
# 3        Visual Studio Code (VSCode)       Sublime ...
# 4        Visual Studio Code (VSCode)   PyCharm    S...
# Name: Useful ide, dtype: object

# %%
table['Preferred Programing language'] = table[table.columns[30:45]].apply(
    lambda x: ' '.join(x.dropna().astype(str)),
    axis=1
)

# %%
Lang =table["Preferred Programing language"]
Lang.head()
# Out:
# 0
# 1                      Java
# 2    Python  SQL C       MATLAB
# 3       Python  SQL      Bash
# 4       Python     C++ Java
# Name: Preferred Programing language, dtype: object

# %%
table['Regularly used ML frameworks'] = table[table.columns[90:106]].apply(
    lambda x: ' '.join(x.dropna().astype(str)),
    axis=1
)

# %%
ML_Frameworks =table["Regularly used ML frameworks"]
ML_Frameworks.head()
# Out:
# 0
# 1    Under 1 year   Scikit-learn    TensorFlow    P...
# 2    1-2 years   Scikit-learn     PyTorch    Xgboos...
# 3    1-2 years   Scikit-learn     PyTorch          ...
# 4    I do not use machine learning methods         ...
# Name: Regularly used ML frameworks, dtype: object

# %%
table['Regularly used NLP methods'] = table[table.columns[128:134]].apply(
    lambda x: ' '.join(x.dropna().astype(str)),
    axis=1
)

# %%
NLP =table["Regularly used NLP methods"]
NLP.head()
# Out:
# 0
# 1
# 2
# 3    Word embeddings/vectors (GLoVe, fastText, word...
# 4
# Name: Regularly used NLP methods, dtype: object

# %%
table['Preferred Cloud Computing'] = table[table.columns[160:172]].apply(
    lambda x: ' '.join(x.dropna().astype(str)),
    axis=1
)

# %%
CC =table["Preferred Cloud Computing"]
CC.head()
# Out:
# 0
# 1
# 2
# 3               Other
# 4
# Name: Preferred Cloud Computing, dtype: object

# %%
table['Preferred Media sources for data science topics'] = table[table.columns[284:296]].apply(
    lambda x: ' '.join(x.dropna().astype(str)),
    axis=1
)

# %%
Media =table["Preferred Media sources for data science topics"]
Media.head()
# Out:
# 0
# 1
# 2    Twitter (data science influencers) Email newsl...
# 3    Twitter (data science influencers)   Kaggle (n...
# 4           Blogs (Towards Data Science, Analytics ...
# Name: Preferred Media sources for data science topics, dtype: object

# %%
table['Regularly used ML Algo'] = table[table.columns[106:120]].apply(
    lambda x: ' '.join(x.dropna().astype(str)),
    axis=1
)

# %%
Output = table[["What is your age (# years)?","What is your gender? - Selected Choice","Most helpful product and platform","Platform",'Regularly used ML Algo', "Preferred Media sources for data science topics", "Preferred Cloud Computing",'Regularly used NLP methods',"Regularly used ML frameworks","Preferred Programing language","Useful ide"]]
Output
# Out:
#       What is your age (# years)? What is your gender? - Selected Choice  \
# 0                           30-34                                    Man
# 1                           30-34                                    Man
# 2                           18-21                                    Man
# 3                           55-59                                    Man
# 4                           45-49                                    Man
# ...                           ...                                    ...
# 23992                       22-24                                    Man
# 23993                       60-69                                    Man
# 23994                       25-29                                    Man
# 23995                       35-39                                  Woman
# 23996                       18-21                                    Man
#
#                        Most helpful product and platform  \
# 0
# ...

# %%
gender_counts = table["What is your gender? - Selected Choice"].value_counts()
gender_counts
# Out:
# Man                        18266
# Woman                       5286
# Prefer not to say            334
# Nonbinary                     78
# Prefer to self-describe       33
# Name: What is your gender? - Selected Choice, dtype: int64

# %%
x = ["Man","Woman","Prefer not to say","Nonbinary","Prefer to self-describe" ]
y = [18266 , 5286 , 334 ,78,33]
plt.bar(x,y,color=["blue","red","green","black","yellow"])
plt.title("Age of ML people")
plt.xticks(x , rotation=90)
plt.ylabel("Number of people")
plt.show()

# %%
product_and_platform_counts = table["Most helpful product and platform"].value_counts()
product_and_platform_counts.head(5)
# Out:
#  Online courses (Coursera, EdX, etc)  Video platforms (YouTube, Twitch, etc) Kaggle (notebooks, competitions, etc)      2691
#  Online courses (Coursera, EdX, etc)                                                                                    2159
#  Online courses (Coursera, EdX, etc)   Kaggle (notebooks, competitions, etc)                                            1623
#  Online courses (Coursera, EdX, etc)  Video platforms (YouTube, Twitch, etc)                                            1575
#    Video platforms (YouTube, Twitch, etc)                                                                               1533
# Name: Most helpful product and platform, dtype: int64

# %%
x = [ "Online courses (Coursera, EdX, etc)  Video platforms (YouTube, Twitch, etc) Kaggle (notebooks, competitions, etc","Online courses (Coursera, EdX, etc","Online courses (Coursera, EdX, etc)   Kaggle (notebooks, competitions, etc","Online courses (Coursera, EdX, etc)  Video platforms (YouTube, Twitch, etc)","Video platforms (YouTube, Twitch, etc)"]
y = [2691,2159,1623,1575,1533]
plt.bar(x,y,color=["red","blue","green","yellow","black"])
plt.title("Most preferred combination of online products and platforms")
plt.xticks(x , rotation=90)
plt.ylabel("Number of people")
plt.show()

# %%
platform_counts = table["Platform"].value_counts()
platform_counts.head(10)
# Out:
#            Other                                                            2802
#           None                                                              2643
#          University Courses (resulting in a university degree)              1999
# Coursera                                                                    1715
#   Kaggle Learn Courses                                                       920
#       Udemy                                                                  751
# Coursera      Udemy                                                          512
# Coursera  Kaggle Learn Courses                                               469
# Coursera         University Courses (resulting in a university degree)       454
# Coursera           Other                                                     304
# Name: Platform, dtype: int64

# %%
y = np.array([2802,2643,1999,1715,920,751,512,469,454,304])
mylabels = ["Other","None","University Courses (resulting in a university degree)","Coursera","Kaggle Learn Courses","Udemy","Coursera Udemy","Coursera  Kaggle Learn","Coursera University Courses (resulting in a university degree","Coursera Other" ]
plt.pie(y, labels = mylabels)
plt.show()

# %%
ML_counts = table["Regularly used ML Algo"].value_counts()
ML_counts.head(10)
# Out:
#                                                                                                                                                     8133
# Linear or Logistic Regression Decision Trees or Random Forests                                                                                      1465
#             None                                                                                                                                    1326
# Linear or Logistic Regression                                                                                                                       1219
# Linear or Logistic Regression Decision Trees or Random Forests Gradient Boosting Machines (xgboost, lightgbm, etc)                                   988
# Linear or Logistic Regression Decision Trees or Random Forests  Bayesian Approaches                                                                  420
# ...

# %%
y = np.array([8133,1465,1326,1219,988,420,407,333,311])
mylabels = ["Linear or Logistic Regression Decision Trees or Random Forests","None","Linear or Logistic Regression","Linear or Logistic Regression Decision Trees or Random Forests Gradient Boosting Machines (xgboost, lightgbm, etc)","Linear or Logistic Regression Decision Trees or Random Forests  Bayesian Approaches","Linear or Logistic Regression Decision Trees or Random Forests Gradient Boosting Machines (xgboost, lightgbm, etc) Bayesian Approaches","Convolutional Neural Networks","Linear or Logistic Regression Decision Trees or Random Forests Convolutional Neural Network","Decision Trees or Random Forests"]
plt.pie(y, labels = mylabels)
plt.show()

# %%
Sources_counts = table["Preferred Media sources for data science topics"].value_counts()
Sources_counts.head(10)
# Out:
#                                                                                                                                                     4306
#      YouTube (Kaggle YouTube, Cloud AI Adventures, etc)                                                                                             1410
#    Kaggle (notebooks, forums, etc)  YouTube (Kaggle YouTube, Cloud AI Adventures, etc)                                                              1383
#           None                                                                                                                                      1268
#    Kaggle (notebooks, forums, etc)                                                                                                                  1049
#    Kaggle (notebooks, forums, etc)  YouTube (Kaggle YouTube, Cloud AI Adventures, etc)  Blogs (Towards Data Science, Analytics Vidhya, etc)          849
# ...

# %%
y = np.array([4306, 1410, 1383, 1268, 1049, 849, 443, 406, 354, 353])
req_labels = ["YouTube (Kaggle YouTube, Cloud AI Adventures, etc) ","Kaggle (notebooks, forums, etc)  YouTube (Kaggle YouTube, Cloud AI Adventures, etc)","None","Kaggle (notebooks, forums, etc)", "Kaggle (notebooks, forums, etc)  YouTube (Kaggle YouTube, Cloud AI Adventures, etc)  Blogs (Towards Data Science, Analytics Vidhya, etc) ", "YouTube (Kaggle YouTube, Cloud AI Adventures, etc)  Blogs (Towards Data Science, Analytics Vidhya, etc) ", "Kaggle (notebooks, forums, etc) Course Forums (forums.fast.ai, Coursera forums, etc) YouTube (Kaggle YouTube, Cloud AI Adventures, etc", "Blogs (Towards Data Science, Analytics Vidhya, etc", "Kaggle (notebooks, forums, etc)" , "Blogs (Towards Data Science, Analytics Vidhya, etc)"]

# %%
fig, ax = plt.subplots()
ax.scatter(y, req_labels, c="green", alpha=0.5, marker=r'$\clubsuit$',
           label="Luck")
ax.set_xlabel("Leprechauns")
ax.set_ylabel("Gold")
ax.legend()
plt.show()

# %%
prog_count = table["Preferred Programing language"].value_counts()
prog_count.head(10)
# Out:
# Python                            3904
#                                   2862
# Python  SQL                       2396
# Python R SQL                      1008
# Python R                           723
# Python     C++                     563
# Python      Java                   360
# Python   C                         337
# Python          MATLAB             335
# Python       Javascript            304
# Name: Preferred Programing language, dtype: int64

# %%
x = [3904,2862,2396,1008,723,563,360,337,335,304]
y = ["Python","Python SQL","Python R SQL","Python and R","Python and C++","Python and Java","Python and C","Python and MATLAB","Python and Javascript" ]

# %%
def gradient_bar(ax, x, y, width=0.5, bottom=0):
    for left, top in zip(x, y):
        right = left + width
        gradient_image(ax, extent=(left, right, bottom, top),
                       cmap=plt.cm.Blues_r, cmap_range=(0, 0.8))


xmin, xmax = xlim = 0, 10
ymin, ymax = ylim = 0, 1

fig, ax = plt.subplots()
ax.set(xlim=xlim, ylim=ylim, autoscale_on=False)

# background image
gradient_image(ax, direction=1, extent=(0, 1, 0, 1), transform=ax.transAxes,
               cmap=plt.cm.RdYlGn, cmap_range=(0.2, 0.8), alpha=0.5)

N = 10
x = np.arange(N) + 0.15
y = np.random.rand(N)
gradient_bar(ax, x, y, width=0.7)
ax.set_aspect('auto')
plt.show()
